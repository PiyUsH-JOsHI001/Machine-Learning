# %% [markdown]
# # Data cleaning

# %%
# HOW TO FIND MISSING VALUES.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv(r"D:\MS OFFICE FILE\MS EXCEL FILE\heart2.csv")

# %%
dataset.head(10)
# Out:
#    age     sex cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   52    male  0       125   212    0        1      168    NaN      1.0
# 1   53    male  0       140   203    1        0      155    1.0      3.1
# 2   70    male  0       145   174    0        1      125    1.0      2.6
# 3   61    male  0       148   203    0        1      161    NaN      0.0
# 4   62  female  0       138   294    1        1      106    NaN      1.9
# 5   58  female  0       100   248    0        0      122    NaN      1.0
# 6   58    male  0       114   318    0        2      140    NaN      4.4
# 7   55    male  0       160   289    0        0      145    1.0      0.8
# 8   46    male  0       120   249    0        0      144    NaN      0.8
# 9   54    male  0       122   286    0        0      116    1.0      3.2
#
#    slope  ca   area  target
# 0      2   2  Urban       0
# 1      0   0  Urban       0
# 2      0   0  Urban       0
# 3      2   1  Urban       0
# ...

# %%
dataset.shape
# Out:
# (1025, 14)

# %%
dataset.isnull()
# Out:
#         age    sex     cp  trestbps   chol    fbs  restecg  thalach  exang  \
# 0     False  False  False     False  False  False    False    False   True
# 1     False  False  False     False  False  False    False    False  False
# 2     False  False  False     False  False  False    False    False  False
# 3     False  False  False     False  False  False    False    False   True
# 4     False  False  False     False  False  False    False    False   True
# ...     ...    ...    ...       ...    ...    ...      ...      ...    ...
# 1020  False  False  False     False  False  False    False    False  False
# 1021  False  False  False     False  False  False    False    False  False
# 1022  False  False  False     False  False  False    False    False  False
# 1023  False  False  False     False  False  False    False    False   True
# 1024  False  False  False     False  False  False    False    False   True
#
#       oldpeak  slope     ca   area  target
# ...

# %%
dataset.isnull().sum()
# Out:
# age           0
# sex           0
# cp            0
# trestbps      0
# chol          0
# fbs           0
# restecg       0
# thalach       0
# exang       680
# oldpeak       0
# slope         0
# ca            0
# area         71
# target        0
# dtype: int64

# %%
(dataset.isnull().sum()/dataset.shape[0])*100
# Out:
# age          0.000000
# sex          0.000000
# cp           0.000000
# trestbps     0.000000
# chol         0.000000
# fbs          0.000000
# restecg      0.000000
# thalach      0.000000
# exang       66.341463
# oldpeak      0.000000
# slope        0.000000
# ca           0.000000
# area         6.926829
# target       0.000000
# dtype: float64

# %%
dataset.isnull().sum().sum()
# Out:
# np.int64(751)

# %%
(dataset.isnull().sum().sum()/(dataset.shape[0]*dataset.shape[1]))*100
# Out:
# np.float64(5.2334494773519165)

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %% [markdown]
# # Handling Missing Values (Droping)

# %%
# by droping column....

# %%
dataset.head(10)
# Out:
#    age     sex cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   52    male  0       125   212    0        1      168    NaN      1.0
# 1   53    male  0       140   203    1        0      155    1.0      3.1
# 2   70    male  0       145   174    0        1      125    1.0      2.6
# 3   61    male  0       148   203    0        1      161    NaN      0.0
# 4   62  female  0       138   294    1        1      106    NaN      1.9
# 5   58  female  0       100   248    0        0      122    NaN      1.0
# 6   58    male  0       114   318    0        2      140    NaN      4.4
# 7   55    male  0       160   289    0        0      145    1.0      0.8
# 8   46    male  0       120   249    0        0      144    NaN      0.8
# 9   54    male  0       122   286    0        0      116    1.0      3.2
#
#    slope  ca   area  target
# 0      2   2  Urban       0
# 1      0   0  Urban       0
# 2      0   0  Urban       0
# 3      2   1  Urban       0
# ...

# %%
dataset.shape
# Out:
# (1025, 14)

# %%
dataset.isnull().sum()
# Out:
# age           0
# sex           0
# cp            0
# trestbps      0
# chol          0
# fbs           0
# restecg       0
# thalach       0
# exang       680
# oldpeak       0
# slope         0
# ca            0
# area         71
# target        0
# dtype: int64

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
dataset.drop(columns=["exang"],inplace=True)

# %%
dataset.shape
# Out:
# (1025, 13)

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
dataset.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'oldpeak', 'slope', 'ca', 'area', 'target'],
#       dtype='object')

# %%
# By droping rows.....

# %%
dataset.dropna(inplace=True)

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
dataset.shape
# Out:
# (954, 13)

# %% [markdown]
# # Handling Missing Values (Imupting category data)

# %%
df=pd.read_csv(r"D:\MS OFFICE FILE\MS EXCEL FILE\heart2.csv")

# %%
df.isnull().sum()
# Out:
# age           0
# sex           0
# cp            0
# trestbps      0
# chol          0
# fbs           0
# restecg       0
# thalach       0
# exang       680
# oldpeak       0
# slope         0
# ca            0
# area         71
# target        0
# dtype: int64

# %%
df.fillna(10).head(10)
# Out:
#    age     sex cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   52    male  0       125   212    0        1      168   10.0      1.0
# 1   53    male  0       140   203    1        0      155    1.0      3.1
# 2   70    male  0       145   174    0        1      125    1.0      2.6
# 3   61    male  0       148   203    0        1      161   10.0      0.0
# 4   62  female  0       138   294    1        1      106   10.0      1.9
# 5   58  female  0       100   248    0        0      122   10.0      1.0
# 6   58    male  0       114   318    0        2      140   10.0      4.4
# 7   55    male  0       160   289    0        0      145    1.0      0.8
# 8   46    male  0       120   249    0        0      144   10.0      0.8
# 9   54    male  0       122   286    0        0      116    1.0      3.2
#
#    slope  ca   area  target
# 0      2   2  Urban       0
# 1      0   0  Urban       0
# 2      0   0  Urban       0
# 3      2   1  Urban       0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   object
#  2   cp        1025 non-null   object
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     345 non-null    float64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  area      954 non-null    object
#  13  target    1025 non-null   int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 112.2+ KB

# %%
df.fillna(method="bfill")
# Out:
# C:\Users\piyush joshi\AppData\Local\Temp\ipykernel_38732\3896554658.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="bfill")
#       age     sex cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    male  0       125   212    0        1      168    1.0      1.0
# 1      53    male  0       140   203    1        0      155    1.0      3.1
# 2      70    male  0       145   174    0        1      125    1.0      2.6
# 3      61    male  0       148   203    0        1      161    1.0      0.0
# 4      62  female  0       138   294    1        1      106    1.0      1.9
# ...   ...     ... ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    male  1       140   221    0        1      164    1.0      0.0
# 1021   60    male  0       125   258    0        0      141    1.0      2.8
# ...

# %%
df.fillna(method="ffill")
# Out:
# C:\Users\piyush joshi\AppData\Local\Temp\ipykernel_38732\3944122520.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill")
#       age     sex cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    male  0       125   212    0        1      168    NaN      1.0
# 1      53    male  0       140   203    1        0      155    1.0      3.1
# 2      70    male  0       145   174    0        1      125    1.0      2.6
# 3      61    male  0       148   203    0        1      161    1.0      0.0
# 4      62  female  0       138   294    1        1      106    1.0      1.9
# ...   ...     ... ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    male  1       140   221    0        1      164    1.0      0.0
# 1021   60    male  0       125   258    0        0      141    1.0      2.8
# ...

# %%
df.fillna(method="bfill",axis=1)
# Out:
# C:\Users\piyush joshi\AppData\Local\Temp\ipykernel_38732\734305466.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="bfill",axis=1)
#      age     sex cp trestbps chol fbs restecg thalach exang oldpeak slope ca  \
# 0     52    male  0      125  212   0       1     168   1.0     1.0     2  2
# 1     53    male  0      140  203   1       0     155   1.0     3.1     0  0
# 2     70    male  0      145  174   0       1     125   1.0     2.6     0  0
# 3     61    male  0      148  203   0       1     161   0.0     0.0     2  1
# 4     62  female  0      138  294   1       1     106   1.9     1.9     1  3
# ...   ..     ... ..      ...  ...  ..     ...     ...   ...     ...   ... ..
# 1020  59    male  1      140  221   0       1     164   1.0     0.0     2  0
# 1021  60    male  0      125  258   0       0     141   1.0     2.8     1  1
# ...

# %%
df.fillna(method="ffill",axis=1)
# Out:
# C:\Users\piyush joshi\AppData\Local\Temp\ipykernel_38732\3252714673.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill",axis=1)
#      age     sex cp trestbps chol fbs restecg thalach exang oldpeak slope ca  \
# 0     52    male  0      125  212   0       1     168   168     1.0     2  2
# 1     53    male  0      140  203   1       0     155   1.0     3.1     0  0
# 2     70    male  0      145  174   0       1     125   1.0     2.6     0  0
# 3     61    male  0      148  203   0       1     161   161     0.0     2  1
# 4     62  female  0      138  294   1       1     106   106     1.9     1  3
# ...   ..     ... ..      ...  ...  ..     ...     ...   ...     ...   ... ..
# 1020  59    male  1      140  221   0       1     164   1.0     0.0     2  0
# 1021  60    male  0      125  258   0       0     141   1.0     2.8     1  1
# ...

# %%
# By mode

# %%
  df["area"].mode()[0]
# Out:
# 'Rular'

# %%
df["area"].fillna(df["area"].mode()[0])
# Out:
# 0       Urban
# 1       Urban
# 2       Urban
# 3       Urban
# 4       Rular
#         ...
# 1020    Rular
# 1021    Urban
# 1022    Rular
# 1023    Rular
# 1024    Urban
# Name: area, Length: 1025, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   object
#  2   cp        1025 non-null   object
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     345 non-null    float64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  area      954 non-null    object
#  13  target    1025 non-null   int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 112.2+ KB

# %%
df.select_dtypes(include="object").columns
# Out:
# Index(['sex', 'cp', 'area'], dtype='object')

# %%
for i in df.select_dtypes(include="object").columns:
    print(i)
# Out:
# sex
# cp
# area

# %%
for i in df.select_dtypes(include="object").columns:
    df[i].fillna(df[i].mode()[0],inplace=True)
# Out:
# C:\Users\piyush joshi\AppData\Local\Temp\ipykernel_38732\3052609891.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[i].fillna(df[i].mode()[0],inplace=True)

# %%
df
# Out:
#       age     sex cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    male  0       125   212    0        1      168    NaN      1.0
# 1      53    male  0       140   203    1        0      155    1.0      3.1
# 2      70    male  0       145   174    0        1      125    1.0      2.6
# 3      61    male  0       148   203    0        1      161    NaN      0.0
# 4      62  female  0       138   294    1        1      106    NaN      1.9
# ...   ...     ... ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    male  1       140   221    0        1      164    1.0      0.0
# 1021   60    male  0       125   258    0        0      141    1.0      2.8
# 1022   47    male  0       110   275    0        0      118    1.0      1.0
# 1023   50  female  0       110   254    0        0      159    NaN      0.0
# 1024   54    male  0       120   188    0        1      113    NaN      1.4
#
#       slope  ca   area  target
# ...

# %% [markdown]
# # Handling Missing Values (SCIKIT-LEARN)

# %%
df.isnull().sum()
# Out:
# age           0
# sex           0
# cp            0
# trestbps      0
# chol          0
# fbs           0
# restecg       0
# thalach       0
# exang       680
# oldpeak       0
# slope         0
# ca            0
# area          0
# target        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   object
#  2   cp        1025 non-null   object
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     345 non-null    float64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  area      1025 non-null   object
#  13  target    1025 non-null   int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 112.2+ KB

# %%
df.select_dtypes(include="float64").columns
# Out:
# Index(['exang', 'oldpeak'], dtype='object')

# %%
from sklearn.impute import SimpleImputer

# %%
si=SimpleImputer(strategy="mean")
arr=si.fit_transform(df[['exang']])

# %%
new_df=pd.DataFrame(arr,columns=["exang"])

# %%
new_df.isnull().sum()
# Out:
# exang    0
# dtype: int64

# %%
new_df
# Out:
#       exang
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
# ...     ...
# 1020    1.0
# 1021    1.0
# 1022    1.0
# 1023    1.0
# 1024    1.0
#
# [1025 rows x 1 columns]
